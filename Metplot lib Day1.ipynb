# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]

# %%
y=[10,20,30,40,50]

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'*b--')
plt.show()

# %%
plt.plot(x,y,linewidth=2.0)
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])

# %%
t=np.arange(0.,5.,0.2)

#red dashes ble squares and green triangles
plt.plot(t,t,'r--',t,t**2,'bs',t,t==3,'g^')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y, color='green', marker='^', linestyle='dashed', mec='r', mfc='b', linewidth=3, markersize=20)

# %%
x=[1,2,3,4,5]
y=[20,20,20,20,20]
plt.plot(x,y, color='green', marker='^', linestyle='dashed', mec='r', mfc='b', linewidth=3, markersize=20)

# %%
x=[3,3,5,5,3]
y=[15,25,25,15,15]
plt.plot(x,y, color='green', marker='^', linestyle='dashed', mec='r', mfc='b', linewidth=3, markersize=20)

# %%
x=[1.5,2.2,2.2,3,1.5]
y=[15,25,25,15,15]
plt.plot(x,y, color='green', marker='^', linestyle='dashed', mec='r', mfc='b', linewidth=3, markersize=20)

# %%
x=[2,2,4,4,2]
y=[20,40,40,20,20]
plt.plot(x,y, color='green', marker='^', linestyle='dashed', mec='r', mfc='b', linewidth=3, markersize=20)

# %%
from matplotlib.patches import Rectangle
from PIL import Image

# %%
from matplotlib.patches import Rectangle
from PIL import Image
plt.imshow(Image.open('nmap-logo-256x256.png'))
plt.gca().add_patch(Rectangle((5,1000),40,80, edgecolor='red' ,facecolor='none' ,lw=4))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 from matplotlib.patches import Rectangle
#       2 from PIL import Image
# ----> 3 plt.imshow(Image.open('nmap-logo-256x256.png'))
#       4 plt.gca().add_patch(Rectangle((5,1000),40,80, edgecolor='red' ,facecolor='none' ,lw=4))
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nmap-logo-256x256.png'

# %%
x=[4,12]
y=[6,6]
x=[4,12]
y1=[8,8]
x1=[4,4]
y2=[6,8]
x2=[12,12]

plt.plot(x,y,x,y1,x1,y2,x2,y2)

# %%
#create  csv file for  student result having student name,marks,percentage
res={"name":["parth","antima","ant"], "python":[70,85,90],"Java":[90,91,92],"cpp":[90,58,85]}
res
# Out:
# {'name': ['parth', 'antima', 'ant'],
#  'python': [70, 85, 90],
#  'Java': [90, 91, 92],
#  'cpp': [90, 58, 85]}

# %%
data=pd.DataFrame(res)
data
# Out:
#      name  python  Java  cpp
# 0   parth      70    90   90
# 1  antima      85    91   58
# 2     ant      90    92   85

# %%
data["Total"]=data["python"]+data["Java"]+["cpp"]
data
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 data["Total"]=data["python"]+data["Java"]+["cpp"]
#       2 data
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:102, in OpsMixin.__add__(self, other)
#     100 @unpack_zerodim_and_defer("__add__")
#     101 def __add__(self, other):
# --> 102     return self._arith_method(other, operator.add)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6259, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
# ...
